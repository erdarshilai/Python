# %%
s1="Core Python"
print(s1)
print(s1[2])
print(s1[-4])
# Out:
# Core Python
# r
# t

# %%
s1="Core Python"
print(s1[1:5:1])
print(s1[0:9:2])
print(s1[::2])
print(s1[::])
print(s1[2:4:1])
print(s1[2::])
print(s1[:4:])
# Out:
# ore
# Cr yh
# Cr yhn
# Core Python
# re
# re Python
# Core

# %%
s1="Core Python"
print(s1[:-3:])
print(s1[-4:-1])
print(s1[:])
print(s1[-6::])
print(s1[-4:-1:-1])
print(s1[-1::-1])
print(s1[::-1])
# Out:
# Core Pyt
# tho
# Core Python
# Python
#
# nohtyP eroC
# nohtyP eroC

# %%
s1="Core Python"
s1[1]="b"
print(s1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-780e2f738737> in <module>
#       1 s1="Core Python"
# ----> 2 s1[1]="b"
#       3 print(s1)
#
# TypeError: 'str' object does not support item assignment

# %%
s1="Core Python"
n=len(s1)
print("length of string is:",n)
# Out:
# length of string is: 11

# %%
s1="Core Python"
for i in s1:
    print(i,end="")
# Out:
# Core Python

# %%
s1="Python"
s2="Programming"
s3=s1+s2
print(s3)
# Out:
# PythonProgramming

# %%
s1="Python"
s2=s1*4
print(s2)
s4=s1[1:3]*3
print(s4)
# Out:
# PythonPythonPythonPython
# ytytyt

# %%
s1="Python Class"
s2="Python"
if s2 in s1:
    print("true")
print(s2 in s1)
# Out:
# true
# True

# %%
s1="Box"
s1="Boy"
if s1==s2:
    print("same")
else:
    print("not same")
print(s1!=s2)
print(s1<s2)
print(s1>s2)
# Out:
# not same
# True
# True
# False

# %%
s1=input("Main string::")
s2=input("enter substring::")
n=s1.index(s2,0,len(s1))
n2=s1.rindex(s2,0,len(s1))

print(n)
print(n2)
# Out:
# Main string::this is that and this is
# enter substring::ARE
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-608eed0bb514> in <module>
#       1 s1=input("Main string::")
#       2 s2=input("enter substring::")
# ----> 3 n=s1.index(s2,0,len(s1))
#       4 n2=s1.rindex(s2,0,len(s1))
#       5
#
# ValueError: substring not found

# %%
s1="THIS IS PYTHON CLASS.PYTHON IS EASY TO LEARN"
n=s1.count("PYTHON")
print(n)
s2="EASY"
n1=s1.count(s2,0,len(s1))
print(n1)
# Out:
# 2
# 1

# %%
s1="one"
s2="two"
s2=s1
print(id(s1))
print(id(s2))
# Out:
# 2158255800112
# 2158255800112

# %%
s1="one,two,three,four"
s2=s1.split(",")
print(s2)
# Out:
# ['one', 'two', 'three', 'four']
