# %%
print("hi my name is Darshil \ni am persuing my degree from lj university")
# Out:
# hi my name is Darshil
# i am persuing my degree from lj university

# %%
a=18
b="Darshil"
c=7621987401
d=5.6
print("My age is",a,"my name is",b,"my phn no is",c,"my hight is",d)
# Out:
# My age is 18 my name isDarshil my phn no is 7621987401 my hight is 5.6

# %%
a=100
b=3
print(f"value of a is {a} value of b is {b} and the sum of this two value is {a+b}")
print(f"value of a is {a} value of b is {b} and the sub of this two value is {a-b}")
print(f"value of a is {a} value of b is {b} and the multi of this two value is {a*b}")
print(f"value of a is {a} value of b is {b} and the div of this two value is {a//b}")
print(f"value of a is {a} value of b is {b} and the modulo of this two value is {a%b}")
# Out:
# value of a is 100 value of b is 3 and the sum of this two value is 103
# value of a is 100 value of b is 3 and the sub of this two value is 97
# value of a is 100 value of b is 3 and the multi of this two value is 300
# value of a is 100 value of b is 3 and the div of this two value is 33
# value of a is 100 value of b is 3 and the modulo of this two value is 1

# %%
a=float(input(f"enter the radius:"))
b=3.14
print(f"the area of circle is {b*a*a} ")
# Out:
# enter the radius:5
# the area of circle is 78.5

# %%
a=float(input(f"enter the number:"))
print(f"that number is divided by 30 and the value of that is {a/30}")
print(f"modulo {a%30}")
print(f"division {a//30}")
# Out:
# enter the number:185
# that number is divided by 30 and the value of that is 6.166666666666667
# modulo 5.0
# division 6.0

# %%
a=int(input(f"enter the no of days:"))
print(f"the no of months is {a//30}")
print(f"the no of days is {a%30}")
# Out:
# enter the no of days:225
# the no of months is 7
# the no of days is 15

# %%
a=int(input(f"enter the number of hours:"))
print(f"the min is {a*60}")
print(f"the sec is {a*3600}")
# Out:
# enter the number of hours:2
# the min is 120
# the sec is 7200

# %%
a=int(input(f"enter the no of days:"))
print(f"the no of year is {a//360}")
b=int(input(f"enter the no of days:"))
print(f"the no of months is {a//30}")
print(f"the no of days is {a%30}")
# Out:
# enter the no of days:399
# the no of year is 1
# the no of months is 9
# the days id9

# %%
import math
a=int(input(f"enter the number"))
b=int(input(f"enter the number"))
print(f"power is {a**b}")
print(f"precidenbt is {(a+b)*(a/b)}")
print(f"is {a is b}")
print(f"is not {a is not b}")
print(math.sqrt(a))
print(math.pi*a**b)
# Out:
# enter the number10
# enter the number5
# power is 100000
# precidenbt is 30.0
# is False
# is not True
# 3.1622776601683795
# 314159.2653589793

# %%
a=123
ans=a%10
print(ans)
b=a//10
c=b%10
print(c)
d=b//10
print(d)
print("ans",ans+c+d)
# Out:
# 3
# 2
# 1
# ans 6

# %%
a=int(input("enter num1="))
b=int(input("enter num2="))
c=int(input("enter num3="))
if(a>b) and (a>c):
    print("a is max")
elif(b>c):
    print("b is max")
else:
    print("c is max")
# Out:
# enter num1=10
# enter num2=20
# enter num3=30
# c is max

# %%
a=int(input("enter num:="))
b=a%10;
print(b)
if(b==0):
    print("Zero")
elif(b==1):
    print("One")
elif(b==2):
    print("Two")
elif(b==3):
    print("Three")
elif(b==4):
    print("Four")
elif(b==5):
    print("Five")
elif(b==6):
    print("Six")
elif(b==7):
    print("Seven")
elif(b==8):
    print("Eight")
elif(b==9):
    print("Ten")
# Out:
# enter num:=6789
# 9
# Ten

# %%
a=int(input("enter num:"))
if(a%4==0)or (a%400==0) and(a%100!=0):
    print("leap")
else:
    print("not leap")
# Out:
# enter num:2001
# not leap

# %%
a=int(input("enter num:"))
for i in range(1,a):
    if(i%3==0):
        print(i)
# Out:
# enter num:15
# 3
# 6
# 9
# 12

# %%
for i in range(1,11):
    if (i==3) or (i==6):
        continue
    else:
        print(i)
# Out:
# 1
# 2
# 4
# 5
# 7
# 8
# 9
# 10

# %%
a=int(input("enter num:"))
for i in range(1,11):
    print(f"{a}*{i}=",a*i)
# Out:
# enter num:6
# 6*1= 6
# 6*2= 12
# 6*3= 18
# 6*4= 24
# 6*5= 30
# 6*6= 36
# 6*7= 42
# 6*8= 48
# 6*9= 54
# 6*10= 60

# %%
n=int(input("enter num:"))
ans=0
sum=0
z=n
while n>0:
    digit=n%10
    ans=digit*digit*digit+ans
    n=n//10
print(ans)
if z==ans:
    print("arm")
else:
    print("not arm")
# Out:
# enter num:153
# 153
# arm

# %%
n=int(input("enter num:"))
esum=0
osum=0
c=0
for n in range(1,101):
    if(i%2==0):
        esum=esum+i
    else:
        osum=+i
print(esum)
print(osum)
# Out:
# enter num:10
# 10000
# 0
